# %%
### import libraries
import pandas as pd
import numpy as np
import os as os
import datetime as dt
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import seaborn as sns
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import binarize
from sklearn.grid_search import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV
import re

# %%
#Set working directory
os.chdir("/Users/halliebregman/Dropbox/Kaggle")

# %%
#Load in data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
prod = pd.read_csv("product_descriptions.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
#Check out first 5 lines
print train.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1   3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2   9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3  16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4  17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
#
#           search_term  relevance
# 0       angle bracket       3.00
# 1           l bracket       2.50
# 2           deck over       3.00
# 3    rain shower head       2.33
# 4  shower only faucet       2.67

# %%
#Merge train and product descriptions
train = pd.DataFrame.merge(train, prod, on="product_uid", how='left')
#train = train[np.isfinite(train.id)]

# %%
#Merge test and product descriptions
test = pd.DataFrame.merge(test, prod, on="product_uid", how='left')
#test = test[np.isfinite(test.id)]

# %%
#If search terms are in product title, flag as true
match = []
for i in range(len(train)):
    if train['search_term'][i] in train['product_title'][i]:
        match.append(True)
    else:
        match.append(False)

# %%
#If search terms are in product title, flag as true
match_t = []
for i in range(len(test)):
    if test['search_term'][i] in test['product_title'][i]:
        match_t.append(True)
    else:
        match_t.append(False)

# %%
#If search terms are in product description, flag as true
match2 = []
for i in range(len(train)):
    if train['search_term'][i] in train['product_description'][i]:
        match2.append(True)
    else:
        match2.append(False)

# %%
#If search terms are in product description, flag as true
match2_t = []
for i in range(len(test)):
    if test['search_term'][i] in test['product_description'][i]:
        match2_t.append(True)
    else:
        match2_t.append(False)

# %%
#Add new values to dataframe
train['match'] = match
train['match2'] = match2
train['match3'] = (match==True) & (match2==True)
test['match'] = match_t
test['match2'] = match2_t
test['match3'] = (match_t==True) & (match2_t==True)

# %%
#Fine all matches for search terms in product description
#match = []
#for i in range(len(train)):
#    matched = re.findall(train['search_term'][i], train['product_description'][i])
#    match.append(matched)

# %%
#Count number of times search term is found in product title/description
def countoverlappingdistinct(pattern, thestring):
  total = 0
  start = 0
  there = re.compile(pattern)
  while True:
    mo = there.search(thestring, start)
    if mo is None: return total
    total += 1
    start = 1 + mo.start()

# %%
#Remove characters
train['search_term'] = train['search_term'].str.lstrip('*')
test['search_term'] = test['search_term'].str.lstrip('*')

# %%
#Count number of matches in product description
count = []
for i in range(len(train)):
    counted = countoverlappingdistinct(train['search_term'][i], train['product_description'][i])
    count.append(counted)

# %%
#Count number of matches in product title
count_title = []
for i in range(len(train)):
    counted = countoverlappingdistinct(train['search_term'][i], train['product_title'][i])
    count_title.append(counted)

# %%
#Count number of matches in product description
count_t = []
for i in range(len(test)):
    counted = countoverlappingdistinct(test['search_term'][i], test['product_description'][i])
    count_t.append(counted)

# %%
#Count number of matches in product title
count_t_title = []
for i in range(len(test)):
    counted = countoverlappingdistinct(test['search_term'][i], test['product_title'][i])
    count_t_title.append(counted)

# %%
train['count'] = count
test['count'] = count_t
train['count_title'] = count_title
test['count_title'] = count_t_title

# %%
sns.set(context="paper", font="monospace")

# Load the datset of correlations between cortical brain networks
#df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)
sub = train[['count', 'count_title', 'relevance']]
corrmat = sub.corr()
#print corrmat

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 9))

# Draw the heatmap using seaborn
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
X = train[['count', 'match2', 'count_title']]
y = train[['relevance']]
y = np.squeeze(y)

# use train/test split with different random_state values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=4)

# instantiate the model 
knn = RandomForestRegressor()

# fit the model with data
knn.fit(X_train, y_train)

# predict the response for new observations
y_pred = knn.predict(X_test)
#y_pred[X_test.totV1 == 0] = 1

print np.sqrt(-cross_val_score(knn, X_train, y_train, cv=10, scoring='mean_squared_error')).mean()

coefs = pd.DataFrame(zip(X.columns, knn.feature_importances_), columns=['features', 'estimatedCoefficients'])
print coefs
#print knn.feature_importances_
sns.stripplot(x="features", y="estimatedCoefficients", data=coefs);
# Out:
# 0.532712138924
#       features  estimatedCoefficients
# 0        count               0.188994
# 1       match2               0.726817
# 2  count_title               0.084189

# %%
#Define train
X_train = train[['count', 'match2', 'count_title']]
y_train = train[['relevance']]
y_train = np.squeeze(y_train)

#Define test
X_test = test[['count', 'match2', 'count_title']]

# instantiate the model 
knn = RandomForestRegressor()

# fit the model with data
knn.fit(X_train, y_train)

# predict the response for new observations
y_pred = knn.predict(X_test)

# %%
#Attach predicted values to test set
for i in range(len(y_pred)):
    test['y_pred'] = y_pred[i]

# %%
writer = test.drop(["count_title", "count", "match", "match2", "match3", "product_uid", "product_title", "search_term", "product_description"], axis=1)

# %%
writer.columns = ['id', 'relevance']

# %%
writer.to_csv("test2.csv")

# %%
###Look at most common search terms
tweets_by_lang = train['search_term'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of searches' , fontsize=15)
#ax.set_y_axis(0, 30)
ax.set_title('Top 5 search terms', fontsize=15, fontweight='bold')
tweets_by_lang[:20].plot(ax=ax, kind='bar', color='red')

# %%
words = []
word_lower = []
for i in range(len(train)):
    words.append(train['search_term'][i].splitlines())
    for row in words:
        for word in row:
            word_lower.append(word.lower())
    
descrip = []
for i in range(len(train)):
    descrip.append(train['product_description'][i].splitlines())
    
title = []
for i in range(len(train)):
    title.append(train['product_title'][i].splitlines())

# %%
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

df_train = pd.read_csv('train.csv', encoding="ISO-8859-1")
df_test = pd.read_csv('test.csv', encoding="ISO-8859-1")
# df_attr = pd.read_csv('../input/attributes.csv')
df_pro_desc = pd.read_csv('product_descriptions.csv')

num_train = df_train.shape[0]

def str_common_word(str1, str2):
	str1, str2 = str1.lower(), str2.lower()
	words, cnt = str1.split(), 0
	for word in words:
		if str2.find(word)>=0:
			cnt+=1
	return cnt

df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')

df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)

df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title']+"\t"+df_all['product_description']

df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))

df_all = df_all.drop(['search_term','product_title','product_description','product_info'],axis=1)

df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']

y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values

clf = RandomForestRegressor(n_estimators=25, max_depth=6)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %%
from PyDictionary import PyDictionary
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
dictionary=PyDictionary()

# %%
dictionary.synonym('9')
# Out:
# 9 has no Synonyms in the API

# %%
def str_common_word(str1, str2):
    syns=[]
    str1, str2 = str1.lower(), str2.lower()
    words, cnt = str1.split(), 0
    for word in words:
        syns.append(dictionary.synonym(word))
        return syns
            #if syns.str.endswith("has no Synonyms in the API"):
            #    syns = 'None'
            #for syn in syns:
            #    if str2.find(syn)>=0:
            #        cnt+=1
        #return cnt

# %%
df_all = df_all[:100]
df_all['synonyms'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
# Out:
# 8 has no Synonyms in the API
# 6 has no Synonyms in the API
# 6 has no Synonyms in the API
# elastomeric has no Synonyms in the API
# 6 has no Synonyms in the API
# /Users/halliebregman/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
df_all['product_description'][0].dtype
type(df_all['product_description'][0])
# Out:
# str

# %%
print df_all.head()
# Out:
#    id                                      product_title  product_uid  \
# 0   2                  Simpson Strong-Tie 12-Gauge Angle       100001
# 1   3                  Simpson Strong-Tie 12-Gauge Angle       100001
# 2   9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...       100002
# 3  16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 4  17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
#
#    relevance         search_term  \
# 0       3.00       angle bracket
# 1       2.50           l bracket
# 2       3.00           deck over
# 3       2.33    rain shower head
# 4       2.67  shower only faucet
#
#                                  product_description  \
# 0  Not only do angles make joints stronger, they ...
# 1  Not only do angles make joints stronger, they ...
# 2  BEHR Premium Textured DECKOVER is an innovativ...
# 3  Update your bathroom with the Delta Vero Singl...
# 4  Update your bathroom with the Delta Vero Singl...
#
# ...

# %%
for i in range(len(df_all)):
    df_all['synonyms'][i] =  ', '.join(df_all['synonyms'][i][0])
# Out:
# /Users/halliebregman/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/halliebregman/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-4e6f8873b5b4> in <module>()
#       1 for i in range(len(df_all)):
# ...

# %%
print str(df_all['word_in_title']).strip('[]')
# Out:
# 0          [[twist, corner, intersection, edge, slant]]
# 1        [[gallant, gritty, bold, fearless, audacious]]
# 2     [[bedeck, embellish, festoon, beautify, decora...
# 3           [[rainfall, deluge, hail, torrent, shower]]
# 4               [[deluge, downpour, rain, flood, hail]]
# 5     [[deportation, transmission, relocation, remov...
# 6                       [[bake, zap, heat, nuke, melt]]
# 7                       [[bake, zap, heat, nuke, melt]]
# 8     [[difficulty, crunch, accident, necessity, ten...
# 9                                          [[mds, rdf]]
# 10          [[steel, stele, steely, steelier, steeled]]
# 11             [[brings, brights, brogues, bigs, brig]]
# 12           [[vapor, smoke, fumes, effluvium, miasma]]
# 13                [[honed, hound, hand, handy, horned]]
# 14    [[hometown, humping, harmattan, tempting, umpt...
# 15    [[dis pose, dis-pose, disposed, despise, dispe...
# 16                [[sear, roast, barbecue, cook, burn]]
# ...

# %%
df_all
# Out:
#      id                                      product_title  product_uid  \
# 0     2                  Simpson Strong-Tie 12-Gauge Angle       100001
# 1     3                  Simpson Strong-Tie 12-Gauge Angle       100001
# 2     9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...       100002
# 3    16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 4    17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...       100005
# 5    18  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 6    20  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 7    21  Whirlpool 1.9 cu. ft. Over the Range Convectio...       100006
# 8    23  Lithonia Lighting Quantum 2-Light Black LED Em...       100007
# 9    27  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...       100009
# 10   34       Valley View Industries Metal Stakes (4-Pack)       100010
# 11   35  Toro Personal Pace Recycler 22 in. Variable Sp...       100011
# ...

# %%
df_train = pd.read_csv('train.csv', encoding="ISO-8859-1")
df_test = pd.read_csv('test.csv', encoding="ISO-8859-1")
# df_attr = pd.read_csv('../input/attributes.csv')
df_pro_desc = pd.read_csv('product_descriptions.csv')
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')
df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title']+"\t"+df_all['product_description']

#df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))
#df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))
